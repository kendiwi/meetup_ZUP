# %% [markdown]
# ### meetUp ZUP - Analisando spectrograms

# %% [markdown]
# ## carregando as bibliotecas

# %%
import librosa
import numpy as np
import IPython.display as ipd
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
from IPython.display import Audio
import warnings
warnings.filterwarnings('ignore')
import datetime
import os

# %% [markdown]
# ## Análise do spectrograma

# %% [markdown]
# ### Trap

# %%
#trap
#benny
audio_path='./musicas/02_min/benny_02_min.wav'
y0_1, sr = librosa.load(audio_path)

# Plot CQT spectorgram total

fig = plt.figure(figsize=(20, 8))
cqt = librosa.cqt(y0_1)
librosa.display.specshow(librosa.amplitude_to_db(cqt, ref = np.max), x_axis = 'time', y_axis = 'cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.show()

#Audio(data = y0_1, rate = sr)

# %%
#trap
#dram - broccoli
audio_path='./musicas/02_min/dram_02_min.wav'
y0_2, sr = librosa.load(audio_path)

# Plot CQT spectorgram total

fig = plt.figure(figsize=(20, 8))
cqt = librosa.cqt(y0_2)
librosa.display.specshow(librosa.amplitude_to_db(cqt, ref = np.max), x_axis = 'time', y_axis = 'cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.show()

#Audio(data = y0_2, rate = sr)

# %%
#trap
#6IX9INE Gotti
audio_path='./musicas/02_min/gotti_02_min.wav'
y0_3, sr = librosa.load(audio_path)

# Plot CQT spectorgram total

fig = plt.figure(figsize=(20, 8))
cqt = librosa.cqt(y0_3)
librosa.display.specshow(librosa.amplitude_to_db(cqt, ref = np.max), x_axis = 'time', y_axis = 'cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.show()

#Audio(data = y0_3, rate = sr)

# %% [markdown]
# ### Brazillian bass

# %%
#brazillian bass
#Alok - ocean
audio_path='./musicas/02_min/alok_02_min.wav'
y1_1, sr = librosa.load(audio_path)

# Plot CQT spectorgram total

fig = plt.figure(figsize=(20, 8))
cqt = librosa.cqt(y1_1)
librosa.display.specshow(librosa.amplitude_to_db(cqt, ref = np.max), x_axis = 'time', y_axis = 'cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.show()

#Audio(data = y1_1, rate = sr)

# %%
#vintage culture - manifesto
audio_path='./musicas/02_min/vintage_02_min.wav'
y1_2, sr = librosa.load(audio_path)

# Plot CQT spectorgram total

fig = plt.figure(figsize=(20, 8))
cqt = librosa.cqt(y1_2)
librosa.display.specshow(librosa.amplitude_to_db(cqt, ref = np.max), x_axis = 'time', y_axis = 'cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.show()

#Audio(data = y1_2, rate = sr)

# %%
#vintage cat dealers - gravity
audio_path='./musicas/02_min/cat_02_min.wav'
y1_3, sr = librosa.load(audio_path)

# Plot CQT spectorgram total

fig = plt.figure(figsize=(20, 8))
cqt = librosa.cqt(y1_3)
librosa.display.specshow(librosa.amplitude_to_db(cqt, ref = np.max), x_axis = 'time', y_axis = 'cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.show()

#Audio(data = y1_3, rate = sr)

# %% [markdown]
# ### Psytrance

# %%
#sajanka - jumpa lumpa
audio_path='./musicas/02_min/sajanka_02_min.wav'
y3_1, sr = librosa.load(audio_path)

# Plot CQT spectorgram total

fig = plt.figure(figsize=(20, 8))
cqt = librosa.cqt(y3_1)
librosa.display.specshow(librosa.amplitude_to_db(cqt, ref = np.max), x_axis = 'time', y_axis = 'cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.show()

#Audio(data = y3_1, rate = sr)

# %%
#menumas - light up the night
audio_path='./musicas/02_min/menumas_02_min2.wav'
y3_2, sr = librosa.load(audio_path)

# Plot CQT spectorgram total

fig = plt.figure(figsize=(20, 8))
cqt = librosa.cqt(y3_2)
librosa.display.specshow(librosa.amplitude_to_db(cqt, ref = np.max), x_axis = 'time', y_axis = 'cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.show()

#Audio(data = y3_2, rate = sr)

# %%
#menumas - universe
audio_path='./musicas/02_min/menumas_02_min.wav'
y3_4, sr = librosa.load(audio_path)

# Plot CQT spectorgram total

fig = plt.figure(figsize=(20, 8))
cqt = librosa.cqt(y3_4)
librosa.display.specshow(librosa.amplitude_to_db(cqt, ref = np.max), x_axis = 'time', y_axis = 'cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.show()

#Audio(data = y4_2, rate = sr)

# %%
#auro vortex - rampage
audio_path='./musicas/02_min/aura_vortex_02_min.wav'
y3_2, sr = librosa.load(audio_path)

# Plot CQT spectorgram total

fig = plt.figure(figsize=(20, 8))
cqt = librosa.cqt(y3_2)
librosa.display.specshow(librosa.amplitude_to_db(cqt, ref = np.max), x_axis = 'time', y_axis = 'cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.show()

#Audio(data = y3_2, rate = sr)

# %% [markdown]
# ## seperando a parte acustica e a harmônica

# %%
#brazillian bass
#Alok - ocean

y_harmonic, y_percussive = librosa.effects.hpss(y1_1)

# %%
# Plot CQT spectorgram total

fig = plt.figure(figsize=(20, 8))

cqt = librosa.cqt(y_harmonic)
librosa.display.specshow(librosa.amplitude_to_db(cqt, ref = np.max), x_axis = 'time', y_axis = 'cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.show()

#Audio(data = y_harmonic, rate = sr)

# %%
# Plot CQT spectorgram total

fig = plt.figure(figsize=(20, 8))

cqt = librosa.cqt(y_percussive)
librosa.display.specshow(librosa.amplitude_to_db(cqt, ref = np.max), x_axis = 'time', y_axis = 'cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.show()

#Audio(data = y_percussive, rate = sr)

# %% [markdown]
# ## Desafio final - adivinhe a música

# %%
#menumas - happiness
audio_path='./musicas/02_min/menumas_final.wav'
y3_2, sr = librosa.load(audio_path)

# Plot CQT spectorgram total

fig = plt.figure(figsize=(20, 8))
cqt = librosa.cqt(y3_2)
librosa.display.specshow(librosa.amplitude_to_db(cqt, ref = np.max), x_axis = 'time', y_axis = 'cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.show()

#Audio(data = y3_2, rate = sr)

# %%
#menumas - happiness
audio_path='./musicas/02_min/happiness_02_min.wav'
y3_2, sr = librosa.load(audio_path)

# Plot CQT spectorgram total

fig = plt.figure(figsize=(20, 8))
cqt = librosa.cqt(y3_2)
librosa.display.specshow(librosa.amplitude_to_db(cqt, ref = np.max), x_axis = 'time', y_axis = 'cqt_note')
plt.colorbar(format='%+2.0f dB')
plt.show()

#Audio(data = y3_2, rate = sr)

# %%
FEATURES=[]
audio_path='./musicas/02_min/happiness_02_min.wav'
y, sr = librosa.load(audio_path)
#capturo a informação já transformada em DB
db=librosa.amplitude_to_db(librosa.cqt(y), ref = np.max)
#corto a musica entre 01:30 até 02:30
db_cut=db[:,0:2584]

DB_frame=[]

for j in range(0,2584):
    DB_count=[]
    for i in range(0,84):
        db_corte= db_cut[i][j]
        if db_corte > -20:
            DB_count.append(db_corte)

    DB_frame.append(len(DB_count))
qtd_high_db=np.sum(DB_frame)

tempo, beats = librosa.beat.beat_track(y=y, sr=sr)
duration=librosa.get_duration(y=y,sr=sr)
duration_min=datetime.timedelta(seconds=duration)
duration_sec=datetime.timedelta(seconds=duration)
chroma = librosa.feature.chroma_stft(y=y, sr=sr)

f1=duration_min
f2=duration
f3=round(tempo,2)
f4=np.sum(np.sum(chroma,axis=0))
f5=np.mean(np.sum(chroma,axis=0))
f6=np.std(np.sum(chroma,axis=0))
f7=round(100*f6/f5,4)
f8=np.max(np.sum(chroma,axis=0))
f9=np.min(np.sum(chroma,axis=0))
f10=qtd_high_db


features=(f1,f2,f3,f4,f5,f6,f7,f8,f9,f10)
FEATURES.append(features)

new_features=pd.DataFrame(list(FEATURES),columns=['duration',
                                                  'duration_sec',
                                                  'bpm',
                                                  'pwr_sum',
                                                  'pwr_mean',
                                                  'pwr_std',
                                                  'pwr_cv',
                                                  'pwr_max',
                                                  'pwr_min',
                                                  'db_high'])
new_features
# Out:
#   duration  duration_sec     bpm       pwr_sum  pwr_mean   pwr_std  pwr_cv  \
# 0 00:02:00         120.0  143.55  34736.953125  6.721547  1.932579  28.752
#
#      pwr_max  pwr_min  db_high
# 0  11.305224  1.52888    46118
